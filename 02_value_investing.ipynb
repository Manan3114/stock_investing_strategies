# %%
import pandas as pd
import numpy as np
import yfinance as yf
import math
from scipy import stats

# %%
tickers = pd.read_csv('top_50_indian_stocks.csv')
tickers.head()
# Out:
#          Ticker               Company Name
# 0   RELIANCE.NS        Reliance Industries
# 1        TCS.NS  Tata Consultancy Services
# 2   HDFCBANK.NS                  HDFC Bank
# 3       INFY.NS                    Infosys
# 4  ICICIBANK.NS                 ICICI Bank

# %%
def fetch_values_of_stocks(tickers):
    
    value_cols = [
        "Ticker", 
        "Price", 
        "PE-Ratio", 
        "PB-Ratio", 
        "PS-Ratio", 
        "EV/EBITDA", 
        "EV/GP"
    ]
    
    value_df = pd.DataFrame(columns=value_cols)
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        price = stock.history(period = "1d")['Close'].iloc[-1]
        
        financials = stock.financials
        balanceSheet = stock.balance_sheet
        cashflow = stock.cashflow
        
        pe_ratio = stock.info.get("forwardPE", np.nan)
        pb_ratio = stock.info.get("priceToBook", np.nan)
        ps_ratio = stock.info.get("priceToSalesTrailing12Months", np.nan)
        ev = stock.info.get("enterpriseValue", np.nan)
        ebitda = stock.info.get("ebitda", np.nan)
        evEbitda = ev / ebitda if ev and ebitda else np.nan
        grossProfit = stock.info.get("grossMargins", np.nan) * stock.info.get("totalRevenue", np.nan)
        evGrossProfit = ev / grossProfit if ev and grossProfit else np.nan
        
        value_df.loc[len(value_df)] = [
            ticker, 
            price, 
            pe_ratio, 
            pb_ratio, 
            ps_ratio, 
            evEbitda, 
            evGrossProfit
        ]
        
    return value_df

# %%
tickers_list = tickers['Ticker'].values.tolist()

df = fetch_values_of_stocks(tickers_list)
df
# Out:
#            Ticker         Price    PE-Ratio    PB-Ratio    PS-Ratio  \
# 0     RELIANCE.NS   1385.699951   19.286013    2.224066    1.920245
# 1          TCS.NS   3083.300049   19.933413   11.393762    4.355161
# 2     HDFCBANK.NS    961.799988    9.981319    2.714702    5.485267
# 3         INFY.NS   1479.000000   20.457687  554.119800  320.520000
# 4    ICICIBANK.NS   1402.099976   36.955720    3.035729    4.933421
# 5   HINDUNILVR.NS   2648.000000   51.655260   12.594051    9.870602
# 6         SBIN.NS    800.750000    9.686102    1.373047    2.125040
# 7   BAJFINANCE.NS    879.650024   21.734291    5.647761   14.093223
# 8   BHARTIARTL.NS   1878.400024   27.896236    9.554959    6.123227
# 9          ITC.NS    405.149994   21.379946    7.239863    6.460229
# 10   KOTAKBANK.NS   1972.900024   17.336958    2.490813    5.281956
# 11    ADANIENT.NS   2251.000000   34.243553    5.447817    2.752661
# 12          LT.NS   3578.600098   34.265470    5.038564    1.830733
# 13     HCLTECH.NS   1444.500000   20.563782  479.867130  279.104700
# 14  ASIANPAINT.NS   2500.800049   88.530460   12.361434    7.081730
# 15    AXISBANK.NS   1055.699951   10.556095    1.687330    4.257008
# 16   SUNPHARMA.NS   1580.300049   48.369030    5.251634    7.052485
# 17       WIPRO.NS    250.850006    9.922864    3.022763    2.959275
# 18  ULTRACEMCO.NS  12654.000000   92.338005    5.264244    4.748202
# 19    HDFCLIFE.NS    767.500000  121.825390    9.720604    1.659411
# 20        ONGC.NS    231.970001    6.492303    0.849710    0.445483
# 21        NTPC.NS    327.700012   13.599004    1.725609    1.702464
# 22   POWERGRID.NS    272.649994   12.818523    2.733169    5.515750
# 23  TATAMOTORS.NS    671.099976   10.436230    2.127147    0.570589
# 24  INDUSINDBK.NS    740.200012    7.663077    0.889100    3.235031
# 25  ADANIGREEN.NS    910.549988   35.565662   13.458326   12.132906
ril = yf.Ticker("RELIANCE.NS")
ril.info
# Out:
# {'address1': 'Maker Chambers IV',
#  'address2': '3rd Floor 222 Nariman Point',
#  'city': 'Mumbai',
#  'zip': '400021',
#  'country': 'India',
#  'phone': '91 22 3555 5000',
#  'fax': '91 22 2204 2268',
#  'website': 'https://www.ril.com',
#  'industry': 'Oil & Gas Refining & Marketing',
#  'industryKey': 'oil-gas-refining-marketing',
#  'industryDisp': 'Oil & Gas Refining & Marketing',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Reliance Industries Limited engages in hydrocarbon exploration and production, oil and chemicals, textile, retail, digital, material and composites, renewables, and financial services businesses worldwide. It operates through Oil to Chemicals, Oil and Gas, Retail, Digital Services, and Others segments. The company produces and markets petroleum products, such as liquefied petroleum gas, propylene, naphtha, gasoline, jet/aviation turbine fuel, kerosene oil, diesel, sulphur, and petroleum coke. It also provides petrochemicals, including high-density and low-density polyethylene (PE), linear low-density PE, polyester fibers and yarns, polypropylene, polyvinyl chloride, purified terephthalic acid, ethylene glycols and oxide, paraxylene, ortho xylene, benzene, linear alkyl benzene and paraffin, poly butadiene rubber, styrene butadiene rubber, butyl rubber, and polyethylene terephthalate. In addition, the company manufactures and markets yarns, fabrics, apparel, and auto furnishings; explores, develops, and produces crude oil and natural gas; and operates various stores comprising neighborhood, supermarket, hypermarket, wholesale cash and carry, specialty, online stores, as well as stores that offer apparel, beauty and cosmetics, accessories, footwear, consumer electronics, connectivity products, and others. Further, the company provides range of digital television, gaming, broadband, and telecommunication services under the Jio brand name; and non-banking financial and insurance broking services. Additionally, it operates news and entertainment platforms, and Network18 and television channels; publishes magazines; and offers highway hospitality and fleet management services. The company was founded in 1957 and is based in Mumbai, India.',
#  'fullTimeEmployees': 403303,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Mukesh Dhirubhai Ambani',
#    'age': 67,
#    'title': 'Chairman & MD',
#    'yearBorn': 1957,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Nikhil Rasiklal Meswani',
#    'age': 58,
#    'title': 'Executive Director',
#    'yearBorn': 1966,
#    'fiscalYear': 2025,
#    'totalPay': 250000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hital Rasiklal Meswani',
#    'age': 56,
#    'title': 'Executive Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2025,
#    'totalPay': 250000000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Panda Madhusudana Siva Prasad',
#    'age': 72,
#    'title': 'Executive Director',
#    'yearBorn': 1952,
#    'fiscalYear': 2025,
#    'totalPay': 199600000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Anant Mukesh Ambani',
#    'title': 'Whole-Time Director',
#    'fiscalYear': 2025,
#    'totalPay': 23100000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Parul  Sharma',
#    'title': 'Group President',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Srikanth  Venkatachari',
#    'age': 58,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mahesh  Marve',
#    'title': 'Head of Technology',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hemen Kanu Modi',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Savithri  Parekh',
#    'title': 'Company Secretary & Compliance Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 10,
#  'compensationRisk': 7,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 9,
#  'governanceEpochDate': 1754006400,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://ril.com/html/investor/investor.html',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1385.9,
#  'open': 1381.1,
#  'dayLow': 1381.1,
#  'dayHigh': 1396.6,
#  'regularMarketPreviousClose': 1385.9,
#  'regularMarketOpen': 1381.1,
#  'regularMarketDayLow': 1381.1,
#  'regularMarketDayHigh': 1396.6,
#  'dividendRate': 5.5,
#  'dividendYield': 0.4,
#  'exDividendDate': 1755129600,
#  'payoutRatio': 0.083000004,
#  'fiveYearAvgDividendYield': 0.44,
#  'beta': 0.218,
#  'trailingPE': 22.970642,
#  'forwardPE': 19.27488,
#  'volume': 2834292,
#  'regularMarketVolume': 2834292,
#  'averageVolume': 10341794,
#  'averageVolume10days': 10377767,
#  'averageDailyVolume10Day': 10377767,
#  'bid': 1384.5,
#  'ask': 1384.7,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 18741159002112,
#  'fiftyTwoWeekLow': 1114.85,
#  'fiftyTwoWeekHigh': 1551.0,
#  'priceToSalesTrailing12Months': 1.9191369,
#  'fiftyDayAverage': 1439.774,
#  'twoHundredDayAverage': 1331.045,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'INR',
#  'tradeable': False,
#  'enterpriseValue': 21860274143232,
#  'profitMargins': 0.083459996,
#  'floatShares': 6605614466,
#  'sharesOutstanding': 13532499968,
#  'heldPercentInsiders': 0.49662998,
#  'heldPercentInstitutions': 0.2859,
#  'impliedSharesOutstanding': 13532499968,
#  'bookValue': 623.048,
#  'priceToBook': 2.2227824,
#  'lastFiscalYearEnd': 1743379200,
#  'nextFiscalYearEnd': 1774915200,
#  'mostRecentQuarter': 1751241600,
#  'earningsQuarterlyGrowth': 0.783,
#  'netIncomeToCommon': 815039971328,
#  'trailingEps': 60.29,
#  'forwardEps': 71.85,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1730073600,
#  'enterpriseToRevenue': 2.239,
#  'enterpriseToEbitda': 12.769,
#  '52WeekChange': -0.08195746,
#  'SandP52WeekChange': 0.15109766,
#  'lastDividendValue': 5.5,
#  'lastDividendDate': 1755129600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 1384.9,
#  'targetHighPrice': 1850.0,
#  'targetLowPrice': 1300.0,
#  'targetMeanPrice': 1637.9143,
#  'targetMedianPrice': 1650.0,
#  'recommendationMean': 1.6,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 35,
#  'totalCash': 2252110036992,
#  'totalCashPerShare': 166.443,
#  'ebitda': 1711935062016,
#  'totalDebt': 3695749890048,
#  'totalRevenue': 9765410308096,
#  'debtToEquity': 36.605,
#  'revenuePerShare': 721.63,
#  'grossProfits': 3476600127488,
#  'earningsGrowth': 0.784,
#  'revenueGrowth': 0.051,
#  'grossMargins': 0.35601002,
#  'ebitdaMargins': 0.17531,
#  'operatingMargins': 0.11929,
#  'financialCurrency': 'INR',
#  'symbol': 'RELIANCE.NS',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Free Realtime Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChange': -1.0,
#  'regularMarketDayRange': '1381.1 - 1396.6',
#  'fullExchangeName': 'NSE',
#  'averageDailyVolume3Month': 10341794,
#  'fiftyTwoWeekLowChange': 270.05005,
#  'fiftyTwoWeekLowChangePercent': 0.24222994,
#  'fiftyTwoWeekRange': '1114.85 - 1551.0',
#  'fiftyTwoWeekHighChange': -166.09998,
#  'fiftyTwoWeekHighChangePercent': -0.10709218,
#  'fiftyTwoWeekChangePercent': -8.195745,
#  'earningsTimestamp': 1752832800,
#  'earningsTimestampStart': 1760349600,
#  'earningsTimestampEnd': 1760349600,
#  'earningsCallTimestampStart': 1745592300,
#  'earningsCallTimestampEnd': 1745592300,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 60.29,
#  'epsForward': 71.85,
#  'epsCurrentYear': 60.51088,
#  'priceEpsCurrentYear': 22.886793,
#  'fiftyDayAverageChange': -54.874023,
#  'fiftyDayAverageChangePercent': -0.038112942,
#  'twoHundredDayAverageChange': 53.85498,
#  'twoHundredDayAverageChangePercent': 0.040460676,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '1.6 - Buy',
#  'cryptoTradeable': False,
#  'corporateActions': [],
#  'regularMarketTime': 1756441889,
#  'exchange': 'NSI',
#  'messageBoardId': 'finmb_878373',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'gmtOffSetMilliseconds': 19800000,
#  'market': 'in_market',
#  'esgPopulated': False,
#  'longName': 'Reliance Industries Limited',
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 820467900000,
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': -0.07218653,
#  'regularMarketPrice': 1384.9,
#  'shortName': 'RELIANCE INDUSTRIES LTD',
#  'trailingPegRatio': None}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticker     50 non-null     object
#  1   Price      50 non-null     float64
#  2   PE-Ratio   50 non-null     float64
#  3   PB-Ratio   50 non-null     float64
#  4   PS-Ratio   50 non-null     float64
#  5   EV/EBITDA  42 non-null     float64
#  6   EV/GP      44 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# ## Taking care of NULL values

# %%
value_cols = [
        "PE-Ratio", 
        "PB-Ratio", 
        "PS-Ratio", 
        "EV/EBITDA", 
        "EV/GP"
    ]

for col in value_cols:
    df[col] = df[col].fillna(df[col].mean())
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticker     50 non-null     object
#  1   Price      50 non-null     float64
#  2   PE-Ratio   50 non-null     float64
#  3   PB-Ratio   50 non-null     float64
#  4   PS-Ratio   50 non-null     float64
#  5   EV/EBITDA  50 non-null     float64
#  6   EV/GP      50 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.1+ KB

# %%
percentile_metrics = {
    "PE-Ratio" : "PE-Ratio_Percentile", 
    "PB-Ratio" : "PB-Ratio_Percentile",
    "PS-Ratio" : "PS-Ratio_Percentile",
    "EV/EBITDA" : "EV/EBITDA_Percentile",
    "EV/GP" : "EV/GP_Percentile"
}


for metric, percentile in percentile_metrics.items():
    df[percentile] = df[metric].apply(lambda x: stats.percentileofscore(df[metric], x) / 100)

df.head()
# Out:
#          Ticker        Price   PE-Ratio    PB-Ratio    PS-Ratio    EV/EBITDA  \
# 0   RELIANCE.NS  1385.699951  19.286013    2.224066    1.920245    12.769336
# 1        TCS.NS  3083.300049  19.933413   11.393762    4.355161    16.551131
# 2   HDFCBANK.NS   961.799988   9.981319    2.714702    5.485267    89.388929
# 3       INFY.NS  1479.000000  20.457687  554.119800  320.520000  1384.975607
# 4  ICICIBANK.NS  1402.099976  36.955720    3.035729    4.933421    89.388929
#
#          EV/GP  PE-Ratio_Percentile  PB-Ratio_Percentile  PS-Ratio_Percentile  \
# 0     6.287860                 0.36                 0.22                 0.24
# 1    11.013403                 0.38                 0.78                 0.48
# 2    54.592285                 0.18                 0.28                 0.64
# 3  1068.062925                 0.40                 1.00                 1.00
# 4    54.592285                 0.70                 0.36                 0.56
#
#    EV/EBITDA_Percentile  EV/GP_Percentile
# 0                  0.22              0.22
# 1                  0.34              0.50
# 2                  0.87              0.91
# 3                  1.00              1.00
# 4                  0.87              0.91

# %%
from statistics import mean 

df['Value Score'] = df[[value for value in percentile_metrics.values()]].mean(axis = 1)

# 43         M&M.NS   3216.199951   24.462767    4.660356    2.306705
# 44   EICHERMOT.NS   6110.500000   29.909496    7.866459    8.672408
# 45         IOC.NS    138.350006    8.052969    1.021674    0.251824
# 46     SBICARD.NS    788.900024   24.095907    5.440877    7.328035
# 47  PIDILITIND.NS   3034.000000  149.827160   15.820870   11.573497
# 48       DMART.NS   4708.899902   90.099480   14.295124    4.971121
# 49     HDFCAMC.NS   5582.000000   44.284010   14.678890   27.691961
#
#       EV/EBITDA        EV/GP  PE-Ratio_Percentile  PB-Ratio_Percentile  \
# 0     12.769336     6.287860                 0.36                 0.22
# 1     16.551131    11.013403                 0.38                 0.78
# 2     89.388929    54.592285                 0.18                 0.28
# 3   1384.975607  1068.062925                 0.40                 1.00
# 4     89.388929    54.592285                 0.70                 0.36
# 5     43.131819    18.959375                 0.82                 0.84
# 6     89.388929    54.592285                 0.12                 0.08
# 7     89.388929    22.994516                 0.46                 0.66
# 8     14.883020    11.305652                 0.56                 0.72
# 9     18.321732    11.100607                 0.44                 0.68
# 10    89.388929    54.592285                 0.32                 0.26
# 11    27.160095     7.729592                 0.62                 0.64
# 12    18.745202     5.931302                 0.66                 0.54
# 13  1359.249317   806.399193                 0.42                 0.98
# 14    43.126717    16.733474                 0.88                 0.82
# 15    89.388929    54.592285                 0.22                 0.12
# 16    23.272470     8.483228                 0.78                 0.56
# 17    13.066419     8.319534                 0.14                 0.34
# 18    28.351147     8.575855                 0.92                 0.58
# 19    97.272121    19.114410                 0.98                 0.74
# 20     5.335859     4.043085                 0.04                 0.02
# 21    10.746694     6.857929                 0.26                 0.14
# 22     9.835133     8.264194                 0.24                 0.30
# 23     6.340955     1.368303                 0.20                 0.20
# 24    89.388929    54.592285                 0.06                 0.04
# 25    24.151087    22.213925                 0.68                 0.86
# 26    58.323148    24.869295                 0.84                 0.94
# 27    51.961612    27.345788                 0.94                 0.76
# 28    19.077934     7.447587                 0.48                 0.48
# 29    23.278845     9.903934                 0.58                 0.50
# 30     4.462267     2.386197                 0.28                 0.24
# 31     6.504888     3.134165                 0.16                 0.10
# 32    13.442422     4.812557                 0.30                 0.38
# 33    11.569435     5.366965                 0.02                 0.32
# 34    12.378746     9.234042                 0.72                 0.42
# 35    17.299610    15.360167                 0.74                 0.44
# 36    16.578837     6.415158                 0.54                 0.40
# 37    43.390547    19.138535                 0.86                 0.96
# 38    46.228892    13.089265                 0.80                 0.80
# 39    22.572058     8.337225                 0.64                 0.52
# 40    13.883326     4.644861                 0.96                 0.16
# 41    11.230502     2.418442                 0.10                 0.18
# 42    16.654615     6.943180                 0.34                 0.60
# 43    15.016463     7.010974                 0.52                 0.46
# 44    37.108706    19.482918                 0.60                 0.70
# 45     8.171171     3.487974                 0.08                 0.06
# 46    89.388929    44.285297                 0.50                 0.62
# 47    49.985993    21.012401                 1.00                 0.92
# 48    66.437244    33.588834                 0.90                 0.88
# 49    31.491899    28.586427                 0.76                 0.90
#
#     PS-Ratio_Percentile  EV/EBITDA_Percentile  EV/GP_Percentile  Value Score
# 0                  0.24                  0.22              0.22        0.252
# 1                  0.48                  0.34              0.50        0.496
# 2                  0.64                  0.87              0.91        0.576
# 3                  1.00                  1.00              1.00        0.880
# 4                  0.56                  0.87              0.91        0.680
# 5                  0.86                  0.66              0.62        0.760
# 6                  0.26                  0.87              0.91        0.448
# 7                  0.92                  0.87              0.74        0.730
# 8                  0.70                  0.30              0.54        0.564
# 9                  0.72                  0.42              0.52        0.556
# 10                 0.62                  0.87              0.91        0.596
# 11                 0.36                  0.56              0.34        0.504
# 12                 0.20                  0.44              0.20        0.408
# 13                 0.98                  0.98              0.98        0.868
# 14                 0.76                  0.64              0.60        0.740
# 15                 0.46                  0.87              0.91        0.516
# 16                 0.74                  0.50              0.42        0.600
# 17                 0.38                  0.24              0.38        0.296
# 18                 0.54                  0.58              0.44        0.612
# 19                 0.16                  0.96              0.64        0.696
# 20                 0.06                  0.04              0.12        0.056
# 21                 0.18                  0.14              0.26        0.196
# 22                 0.66                  0.12              0.36        0.336
# 23                 0.08                  0.06              0.02        0.112
# 24                 0.44                  0.87              0.91        0.464
# 25                 0.90                  0.54              0.72        0.740
# 26                 0.60                  0.76              0.76        0.780
# 27                 0.94                  0.74              0.78        0.832
# 28                 0.32                  0.46              0.32        0.412
# 29                 0.40                  0.52              0.48        0.496
# 30                 0.22                  0.02              0.04        0.160
# 31                 0.04                  0.08              0.08        0.092
# 32                 0.14                  0.26              0.16        0.248
# 33                 0.42                  0.18              0.18        0.224
# 34                 0.28                  0.20              0.46        0.416
# 35                 0.82                  0.40              0.58        0.596
# 36                 0.52                  0.36              0.24        0.412
# 37                 0.80                  0.68              0.66        0.792
# 38                 0.50                  0.70              0.56        0.672
# 39                 0.68                  0.48              0.40        0.544
# 40                 0.12                  0.28              0.14        0.332
# 41                 0.10                  0.16              0.06        0.120
# 42                 0.34                  0.38              0.28        0.388
# 43                 0.30                  0.32              0.30        0.380
# 44                 0.84                  0.62              0.68        0.688
# 45                 0.02                  0.10              0.10        0.072
# 46                 0.78                  0.87              0.84        0.722
# 47                 0.88                  0.72              0.70        0.844
# 48                 0.58                  0.78              0.82        0.792
# 49                 0.96                  0.60              0.80        0.804

# %%
df = df.sort_values(by="Value Score", ascending=False)
df
# Out:
#            Ticker         Price    PE-Ratio    PB-Ratio    PS-Ratio  \
# 3         INFY.NS   1479.000000   20.457687  554.119800  320.520000
# 13     HCLTECH.NS   1444.500000   20.563782  479.867130  279.104700
# 47  PIDILITIND.NS   3034.000000  149.827160   15.820870   11.573497
# 27    DIVISLAB.NS   6110.000000  108.525760   10.835813   16.804968
# 49     HDFCAMC.NS   5582.000000   44.284010   14.678890   27.691961
# 37   BRITANNIA.NS   5821.000000   71.537420   32.189743    7.738199
# 48       DMART.NS   4708.899902   90.099480   14.295124    4.971121
# 26       TITAN.NS   3613.600098   64.321820   27.599058    5.031039
# 5   HINDUNILVR.NS   2648.000000   51.655260   12.594051    9.870602
# 14  ASIANPAINT.NS   2500.800049   88.530460   12.361434    7.081730
# 25  ADANIGREEN.NS    910.549988   35.565662   13.458326   12.132906
# 7   BAJFINANCE.NS    879.650024   21.734291    5.647761   14.093223
# 14    43.126717    16.733474                 0.88                 0.82
# 25    24.151087    22.213925                 0.68                 0.86
# 7     89.388929    22.994516                 0.46                 0.66
# 46    89.388929    44.285297                 0.50                 0.62
# 19    97.272121    19.114410                 0.98                 0.74
# 44    37.108706    19.482918                 0.60                 0.70
# 4     89.388929    54.592285                 0.70                 0.36
# 38    46.228892    13.089265                 0.80                 0.80
# 18    28.351147     8.575855                 0.92                 0.58
# 16    23.272470     8.483228                 0.78                 0.56
# 10    89.388929    54.592285                 0.32                 0.26
# 35    17.299610    15.360167                 0.74                 0.44
# 2     89.388929    54.592285                 0.18                 0.28
# 8     14.883020    11.305652                 0.56                 0.72
# 9     18.321732    11.100607                 0.44                 0.68
# 39    22.572058     8.337225                 0.64                 0.52
# 15    89.388929    54.592285                 0.22                 0.12
# 11    27.160095     7.729592                 0.62                 0.64
# 1     16.551131    11.013403                 0.38                 0.78
# 29    23.278845     9.903934                 0.58                 0.50
# 24    89.388929    54.592285                 0.06                 0.04
# 6     89.388929    54.592285                 0.12                 0.08
# 34    12.378746     9.234042                 0.72                 0.42
# 28    19.077934     7.447587                 0.48                 0.48
# 36    16.578837     6.415158                 0.54                 0.40
# 12    18.745202     5.931302                 0.66                 0.54
# 42    16.654615     6.943180                 0.34                 0.60
# 43    15.016463     7.010974                 0.52                 0.46
# 22     9.835133     8.264194                 0.24                 0.30
# 40    13.883326     4.644861                 0.96                 0.16
# 17    13.066419     8.319534                 0.14                 0.34
# 0     12.769336     6.287860                 0.36                 0.22
# 32    13.442422     4.812557                 0.30                 0.38
# 33    11.569435     5.366965                 0.02                 0.32
# 21    10.746694     6.857929                 0.26                 0.14
# 30     4.462267     2.386197                 0.28                 0.24
# 41    11.230502     2.418442                 0.10                 0.18
# 23     6.340955     1.368303                 0.20                 0.20
# 31     6.504888     3.134165                 0.16                 0.10
# 45     8.171171     3.487974                 0.08                 0.06
# 20     5.335859     4.043085                 0.04                 0.02
#
#     PS-Ratio_Percentile  EV/EBITDA_Percentile  EV/GP_Percentile  Value Score
# 3                  1.00                  1.00              1.00        0.880
# 13                 0.98                  0.98              0.98        0.868
# 47                 0.88                  0.72              0.70        0.844
# 27                 0.94                  0.74              0.78        0.832
# 49                 0.96                  0.60              0.80        0.804
# 37                 0.80                  0.68              0.66        0.792
# 48                 0.58                  0.78              0.82        0.792
# 26                 0.60                  0.76              0.76        0.780
# 5                  0.86                  0.66              0.62        0.760
# 14                 0.76                  0.64              0.60        0.740
# 25                 0.90                  0.54              0.72        0.740
# 7                  0.92                  0.87              0.74        0.730
# 46                 0.78                  0.87              0.84        0.722
# 19                 0.16                  0.96              0.64        0.696
# 44                 0.84                  0.62              0.68        0.688
# 4                  0.56                  0.87              0.91        0.680
# 38                 0.50                  0.70              0.56        0.672
# 18                 0.54                  0.58              0.44        0.612
# 16                 0.74                  0.50              0.42        0.600
# 10                 0.62                  0.87              0.91        0.596
# 35                 0.82                  0.40              0.58        0.596
# 2                  0.64                  0.87              0.91        0.576
# 8                  0.70                  0.30              0.54        0.564
# 9                  0.72                  0.42              0.52        0.556
# 39                 0.68                  0.48              0.40        0.544
# 15                 0.46                  0.87              0.91        0.516
# 11                 0.36                  0.56              0.34        0.504
# 1                  0.48                  0.34              0.50        0.496
# 29                 0.40                  0.52              0.48        0.496
# 24                 0.44                  0.87              0.91        0.464
# 6                  0.26                  0.87              0.91        0.448
# 34                 0.28                  0.20              0.46        0.416
# 28                 0.32                  0.46              0.32        0.412
# 36                 0.52                  0.36              0.24        0.412
# 12                 0.20                  0.44              0.20        0.408
# 42                 0.34                  0.38              0.28        0.388
# 43                 0.30                  0.32              0.30        0.380
# 22                 0.66                  0.12              0.36        0.336
# 40                 0.12                  0.28              0.14        0.332
# 17                 0.38                  0.24              0.38        0.296
# 0                  0.24                  0.22              0.22        0.252
# 32                 0.14                  0.26              0.16        0.248
# 33                 0.42                  0.18              0.18        0.224
# 21                 0.18                  0.14              0.26        0.196
# 30                 0.22                  0.02              0.04        0.160
# 41                 0.10                  0.16              0.06        0.120
# 23                 0.08                  0.06              0.02        0.112
# 31                 0.04                  0.08              0.08        0.092
# 45                 0.02                  0.10              0.10        0.072
# 20                 0.06                  0.04              0.12        0.056

# %%
df.head(10)
# Out:
#            Ticker        Price    PE-Ratio    PB-Ratio    PS-Ratio  \
# 3         INFY.NS  1479.000000   20.457687  554.119800  320.520000
# 13     HCLTECH.NS  1444.500000   20.563782  479.867130  279.104700
# 47  PIDILITIND.NS  3034.000000  149.827160   15.820870   11.573497
# 27    DIVISLAB.NS  6110.000000  108.525760   10.835813   16.804968
# 49     HDFCAMC.NS  5582.000000   44.284010   14.678890   27.691961
# 37   BRITANNIA.NS  5821.000000   71.537420   32.189743    7.738199
# 48       DMART.NS  4708.899902   90.099480   14.295124    4.971121
# 26       TITAN.NS  3613.600098   64.321820   27.599058    5.031039
# 5   HINDUNILVR.NS  2648.000000   51.655260   12.594051    9.870602
# 14  ASIANPAINT.NS  2500.800049   88.530460   12.361434    7.081730
#
#       EV/EBITDA        EV/GP  PE-Ratio_Percentile  PB-Ratio_Percentile  \
# 3   1384.975607  1068.062925                 0.40                 1.00
# 13  1359.249317   806.399193                 0.42                 0.98
# 47    49.985993    21.012401                 1.00                 0.92
# 27    51.961612    27.345788                 0.94                 0.76
# 49    31.491899    28.586427                 0.76                 0.90
# 37    43.390547    19.138535                 0.86                 0.96
# 48    66.437244    33.588834                 0.90                 0.88
# 26    58.323148    24.869295                 0.84                 0.94
# 5     43.131819    18.959375                 0.82                 0.84
# 14    43.126717    16.733474                 0.88                 0.82
#
#     PS-Ratio_Percentile  EV/EBITDA_Percentile  EV/GP_Percentile  Value Score
# 3                  1.00                  1.00              1.00        0.880
# 13                 0.98                  0.98              0.98        0.868
# 47                 0.88                  0.72              0.70        0.844
# 27                 0.94                  0.74              0.78        0.832
# 49                 0.96                  0.60              0.80        0.804
# 37                 0.80                  0.68              0.66        0.792
# 48                 0.58                  0.78              0.82        0.792
# 26                 0.60                  0.76              0.76        0.780
# 5                  0.86                  0.66              0.62        0.760
# 14                 0.76                  0.64              0.60        0.740
